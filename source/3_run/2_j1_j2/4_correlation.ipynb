# %%
# %run lib/1_config_nets.ipynb
# %run lib/2_config_plot.ipynb
# %run lib/3_load.ipynb
# %run lib/4_config_plot_j1j2.ipynb
# %run lib/5_config_plot_pca.ipynb
# %run lib/6_config_plot_correl_peason.ipynb

# %%
wTs = [45, 210,300]
iLs = [3, 70, 72]
rs  = ['Frustrado','Ferromagnético','Antiferromagnético']

# %% [markdown]
# ### Correlação de Pearson

# %%
L = 8; wT = 210; it = 500; ll = str(L)
kernel_bias = 'kernel'; real_img = 'real'; stride = 5
path    = fr"data/server/L_{L}/it_{it}_l_{L}"; ex_0    = "00"
extEgsL = []; itsNetL = []; netEgsL = []
dfs     = []

for j, wT in enumerate(wTs):
    
    ex_n = iLs[j];    
    df_w = w_net(path,ex_n,L,wT,it,kernel_bias,real_img);

    exact_gs_energy             = f_exact_gs_energy(path,ex_0,ll,wT)
    iters_Net_ds, energy_Net_ds = f_ffnn(path,ex_n, ll, wT, it,stride)


    dfs.append(df_w)

    extEgsL.append(exact_gs_energy)
    itsNetL.append(iters_Net_ds)
    energy_Net_ds.append(energy_Net_ds)

# %%
len(wTs)
# Out:
# 3

# %%
str_nets= "FFNN"
path_img = f"fig/L_{L}/CORR_PEARSON/"; T = "3_R"; it = 500

# %%
plot_correlation(dfs[0], dfs[1], dfs[2], 
                 wTs, iLs,rs,
                 8, 500, 
                 str_nets, T, False, path_img)
# Out:
# Figura salva em: fig/L_8/CORR_PEARSON/CORR_PEARSON_L_8_FFNN_3_R.png

# %%
wTs =[45, 45,45]
iLs = [3, 4, 11]
rs  = ['Frustrado','Frustrado','Frustrado']

# %%
extEgsL = []; itsNetL = []; netEgsL = []
dfs     = []

for j, wT in enumerate(wTs):
    
    ex_n = iLs[j];    
    df_w = w_net(path,ex_n,L,wT,it,kernel_bias,real_img);

    exact_gs_energy             = f_exact_gs_energy(path,ex_0,ll,wT)
    iters_Net_ds, energy_Net_ds = f_ffnn(path,ex_n, ll, wT, it,stride)


    dfs.append(df_w)

    extEgsL.append(exact_gs_energy)
    itsNetL.append(iters_Net_ds)
    energy_Net_ds.append(energy_Net_ds)

# %%
T = "3_W45"

# %%
plot_correlation(dfs[0], dfs[1], dfs[2], 
                 wTs, iLs,rs,
                 8, 500, 
                 str_nets, T, False, path_img)
# Out:
# Figura salva em: fig/L_8/CORR_PEARSON/CORR_PEARSON_L_8_FFNN_3_W45.png

# %%
wTs = [30, 60,120]
iLs = [51, 3, 94]
rs  = ['Frustrado-1','Frustrado-1','Frustrado-2']
T = "3_W45_2F1_F2"
extEgsL = []; itsNetL = []; netEgsL = []
dfs     = []

for j, wT in enumerate(wTs):
    
    ex_n = iLs[j];    
    df_w = w_net(path,ex_n,L,wT,it,kernel_bias,real_img);

    exact_gs_energy             = f_exact_gs_energy(path,ex_0,ll,wT)
    iters_Net_ds, energy_Net_ds = f_ffnn(path,ex_n, ll, wT, it,stride)


    dfs.append(df_w)

    extEgsL.append(exact_gs_energy)
    itsNetL.append(iters_Net_ds)
    energy_Net_ds.append(energy_Net_ds)  

plot_correlation(dfs[0], dfs[1], dfs[2], 
                 wTs, iLs,rs,
                 8, 500, 
                 str_nets, T, False, path_img)
# Out:
# Figura salva em: fig/L_8/CORR_PEARSON/CORR_PEARSON_L_8_FFNN_3_W45_2F1_F2.png

# %%
wTs = [45, 120,150]
iLs = [3, 94,2]
rs  = ['Frustrado-1','Frustrado-2','Frustrado-2']
T = "3_W45_F1_2F2"
extEgsL = []; itsNetL = []; netEgsL = []
dfs     = []

for j, wT in enumerate(wTs):
    
    ex_n = iLs[j];    
    df_w = w_net(path,ex_n,L,wT,it,kernel_bias,real_img);

    exact_gs_energy             = f_exact_gs_energy(path,ex_0,ll,wT)
    iters_Net_ds, energy_Net_ds = f_ffnn(path,ex_n, ll, wT, it,stride)


    dfs.append(df_w)

    extEgsL.append(exact_gs_energy)
    itsNetL.append(iters_Net_ds)
    energy_Net_ds.append(energy_Net_ds)  
    
plot_correlation(dfs[0], dfs[1], dfs[2], 
                 wTs, iLs,rs,
                 8, 500, 
                 str_nets, T, False, path_img)
# Out:
# Figura salva em: fig/L_8/CORR_PEARSON/CORR_PEARSON_L_8_FFNN_3_W45_F1_2F2.png

# %%
T = "3_FR"

# %%
wTs
# Out:
# [45, 210, 300]

# %%
str_nets= "FFNN"
path_img = f"fig/L_{L}/CORR_PEARSON_HIST/"; T = "3_R"; it = 500

# %%
# %run lib/6_config_plot_correl_peason.ipynb

# %%
path_img = f"fig/L_{L}/CORR_PEARSON_BOX/";
plot_correlation_box_by_angle(dfs, wTs, 8, 500, str_nets, T, 1, path_img)
# Out:
# Figura salva em: fig/L_8/CORR_PEARSON_BOX/CORR_BOX_L_8_FFNN_3_R.png

# %%
path_img = f"fig/L_{L}/CORR_PEARSON_BOX/";
plot_correlation_box_by_angle(dfs, wTs, 8, 500, str_nets, T, 1, path_img)
# Out:
# Figura salva em: fig/L_8/CORR_PEARSON_BOX/CORR_BOX_L_8_FFNN_3_R.png
