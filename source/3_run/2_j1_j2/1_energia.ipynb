# %%
# %run lib/1_config_nets.ipynb
# %run lib/2_config_plot.ipynb
# %run lib/3_load.ipynb
# %run lib/4_config_plot_j1j2.ipynb

# %% [markdown]
# ### Energy

# %%
i  = 10
egs_plot('45',str(digts(i)),0)

# %%
for i in range(0,51):
    egs_plot('330',str(digts(i)),0)
    break;

# %% [markdown]
# ### JOBS

# %%
# %run lib/4_config_plot_j1j2.ipynb
ws = [0,30,45,60,120,150,210,225,245,300,330]
ws = [45]
th = 0.70   #janela de corte do envelope de dados para distribuição de dados
stride = 10; opc = "a"; str_nets = "FFNN"
for w in ws:
    ex_0 = '00'; L = 8; ll = '8'; wT = str(w); it = 500; j_lim = 100
    path = fr"data/server/L_{L}/it_{it}_l_{ll}"
    df__,df_,df = run_job(ex_0, wT,stride, ll, it, j_lim, th, opc, 0, 0, path)

# %% [markdown]
# ### SELECT JOB

# %%
ws = [120]
th = 0.70; stride = 10; opc = "a"
l_info = ['FFNN'];str_nets = l_info[0]; stride = 20
for w in ws:
    print("---------------------", w)
    ex_0 = '00'; L = 8; ll = '8'; wT = str(w); it = 500; j_lim = 100
    path = fr"data/server/L_{L}/it_{it}_l_{ll}"
    df__,df_,df  = run_job(ex_0, wT,stride, ll, it, j_lim, th, opc, 1, 0, path)  
    e, j = min_job(df__)
    i  = j - 1; w = str(ws[0])
    egs_plot(w,str(digts(i)),0)
    print("---------------------")
# Out:
# --------------------- 120
# ---------------------

# %%
ex_0 = '00'; L = 8; ll = '8'
th = 0.70; stride = 10; opc = "a"
l_info = ['FFNN'];str_nets = l_info[0]; stride = 20
wTs  = []; iLs = []; wL = []
w   = str(45) ; wL.append(w)
w   = str(210); wL.append(w)
w   = str(300); wL.append(w)
for w in wL:
    ex_0 = '00'; L = 8; ll = '8'; wT = str(w); it = 500; j_lim = 100
    path = fr"data/server/L_{L}/it_{it}_l_{ll}"
    df__,df_,df  = run_job(ex_0, wT,stride, ll, it, j_lim, th, opc, 1, 0, path)  
    e, j         = min_job(df__)
    i  = j; 
    print(i,w)
    
    iLs.append(i)
    wTs.append(w)
# Out:
# 3 45
# 70 210
# 72 300

# %%
# %run lib/4_config_plot_j1j2.ipynb
n_egs_plot(wTs,iLs,1)
# Out:
# fig/L_8/N_EGS/it_500_l_8_w_300/N_EGS_L_8_IT_500_W_45_J_3_W_210_J_70_W_300_J_72_FFNN.png

# %%
ex_0 = '00'; L = 8; ll = '8'
th = 0.70; stride = 10; opc = "a"
l_info = ['FFNN'];str_nets = l_info[0]; stride = 20
wTs  = []; iLs = []; wL = []
w   = str(30) ; wL.append(w)
w   = str(45) ; wL.append(w)
w   = str(60) ; wL.append(w)
w   = str(120) ; wL.append(w)
w   = str(150) ; wL.append(w)
for w in wL:
    ex_0 = '00'; L = 8; ll = '8'; wT = str(w); it = 500; j_lim = 100
    path = fr"data/server/L_{L}/it_{it}_l_{ll}"
    df__,df_,df  = run_job(ex_0, wT,stride, ll, it, j_lim, th, opc, 1, 0, path)  
    e, j         = min_job(df__)
    i  = j; 
    print(i,w)
    
    iLs.append(i)
    wTs.append(w)
# Out:
# 51 30
# 3 45
# 3 60
# 94 120
# 2 150

# %%
i = 3; w = 45
egs_plot(w,str(digts(i)),1)

# %%
iLs, wL
# Out:
# ([51, 3, 3, 94, 2], ['30', '45', '60', '120', '150'])

# %%
# %run lib/4_config_plot_j1j2.ipynb
n_egs_plot(wTs,iLs,1)
# Out:
# fig/L_8/N_EGS/it_500_l_8_w_150/N_EGS_L_8_IT_500_W_30_J_51_W_45_J_3_W_60_J_3_W_120_J_94_W_150_J_2_FFNN.png

# %%
e,j = med_job(df__)
i  = j-1; w = str(ws[0])
egs_plot(w,str(digts(i)),1)

# %%
wT = 45
df__,df_,df  = run_job(ex_0, wT,stride, ll, it, j_lim, th, opc, 1, 0, path)

# %%
w = 45
df_out = df[df['F_Egs'] >-4]

# %%
df_out.head()
# Out:
#     id     F_Egs
# 11  12 -2.831565

# %%
w
# Out:
# 45

# %%
i = 11
egs_plot(w,str(digts(i)),1)

# %%
### T
