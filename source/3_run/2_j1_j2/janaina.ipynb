# %%
# %run 0_config_plot.ipynb
# %run 0_config_nets.ipynb

# %%
for i in itens:
    print(i)
    df = pd.read_csv(i)
    plot_corr_sum_bars(df)
    plot_corr_sum_horizontal_bars(df)
# Out:
# ./w_72_L_8_IT_100_corr_sum.csv
# ...
# RESUMO ESTATÍSTICO POR CATEGORIA
# ...
# Categoria            Média    Std      n      w
# ------------------------------------------------------------
# Antiferromagnético   17.176   10.489   22     0-359
# Frustrado            15.508   13.224   28     23-160
# Ferromagnético       13.749   8.856   22     161-270
# ./w_72_L_20_corr_sum.csv
# ...
# RESUMO ESTATÍSTICO POR CATEGORIA
# ...
# Categoria            Média    Std      n      w
# ------------------------------------------------------------
# Antiferromagnético   170.854   165.816   22     0-359
# Frustrado            141.986   125.096   28     23-160
# Ferromagnético       193.995   175.701   22     161-270
# ./w_15_corr_sum.csv
# ...
# RESUMO ESTATÍSTICO POR CATEGORIA
# ...
# Categoria            Média    Std      n      w
# ------------------------------------------------------------
# Antiferromagnético   59.820   51.201   7      0-359
# Frustrado            61.326   42.177   9      23-160
# ...

# %%
for i in itens:
    print(i)
    df = pd.read_csv(i)
    plot_corr_sum_mean(df)
# Out:
# ./w_72_L_8_IT_100_corr_sum.csv
# antiferromagnético: 17.176 (n=22, w_avg=245.7)
# frustrado: 15.508 (n=28, w_avg=92.5)
# ferromagnético: 13.749 (n=22, w_avg=217.5)
# Estatísticas detalhadas:
#   antiferromagnético   | Média: 17.176 ± 10.489 | n: 22 | w: 0-355
#   frustrado            | Média: 15.508 ± 13.224 | n: 28 | w: 25-160
#   ferromagnético       | Média: 13.749 ± 8.856 | n: 22 | w: 165-270
# ./w_72_L_20_corr_sum.csv
# antiferromagnético: 170.854 (n=22, w_avg=245.7)
# frustrado: 141.986 (n=28, w_avg=92.5)
# ferromagnético: 193.995 (n=22, w_avg=217.5)
# Estatísticas detalhadas:
#   antiferromagnético   | Média: 170.854 ± 165.816 | n: 22 | w: 0-355
#   frustrado            | Média: 141.986 ± 125.096 | n: 28 | w: 25-160
#   ferromagnético       | Média: 193.995 ± 175.701 | n: 22 | w: 165-270
# ./w_15_corr_sum.csv
# antiferromagnético: 59.820 (n=7, w_avg=227.1)
# frustrado: 61.326 (n=9, w_avg=90.0)
# ferromagnético: 70.256 (n=8, w_avg=217.5)
# Estatísticas detalhadas:
# ...

# %%
for i in itens:
    print(i)
    df = pd.read_csv(i)
    plot_corr_sum(df)
# Out:
# ./w_72_L_8_IT_100_corr_sum.csv
# ./w_72_L_20_corr_sum.csv
# ./w_15_corr_sum.csv

# %%
plot_corr_sum_mean

# %%
for i in itens:
    print(i)
    df = pd.read_csv(i)
    plot_corr_sum_mean(df)
# Out:
# ./w_72_L_8_IT_100_corr_sum.csv
# Médias por intervalo:
#   0-22 (antiferromagnético): 21.148 (n=5)
#   23-160 (frustrado): 15.508 (n=28)
#   161-270 (ferromagnético): 13.749 (n=22)
#   271-359 (antiferromagnético): 16.008 (n=17)
# ./w_72_L_20_corr_sum.csv
# Médias por intervalo:
#   0-22 (antiferromagnético): 292.578 (n=5)
#   23-160 (frustrado): 141.986 (n=28)
#   161-270 (ferromagnético): 193.995 (n=22)
#   271-359 (antiferromagnético): 135.053 (n=17)
# ./w_15_corr_sum.csv
# Médias por intervalo:
#   0-22 (antiferromagnético): 89.651 (n=2)
#   23-160 (frustrado): 61.326 (n=9)
#   161-270 (ferromagnético): 70.256 (n=8)
#   271-359 (antiferromagnético): 47.888 (n=5)

# %%
index = 2
itens[2]
df = pd.read_csv(itens[2])
plot_corr_sum(df)

# %%
itens[1]
df = pd.read_csv(itens[1])
plot_corr_sum(df)

# %%
plot_corr_sum(df)

# %%
plot_corr_sum(df)

# %%
pasta = "./*.csv"
itens = glob.glob(pasta)
print(itens)
# Out:
# ['./w_72_L_8_IT_100_corr_sum.csv', './w_72_L_20_corr_sum.csv', './w_15_corr_sum.csv']

# %%
itens[0]
# Out:
# './w_72_L_8_IT_100_corr_sum.csv'

# %%
df = pd.read_csv(itens[0])
