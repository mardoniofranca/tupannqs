# %%
# %run 0_config.ipynb

# %%
plot(float(exact_energy),files,lT,wT, L,it, 
             float(g_jt.energy.mean.real),   
             float(g_fn.energy.mean.real),
             float(g_nfn.energy.mean.real),  
             float(g_rb.energy.mean), 
             oxT, oyT,-70,30, nT, dT)   
print(exact_energy)
# Out:
# ---------------------------
# [-5.43403946]

# %%
ls  = ['(a)','(b)','(c)','(d)','(e)','(f)']  
ws  = [270,300,315,330,340,0]

ws  = [270,300]
ns  = [30,30
ds  = [20,18]
oxs = [False, True]
oys = [True, True,]



ns  = [30,30,35,55,34,0]
ds  = [20,18,20,30,18,0]

oxs = [False, False, False, False, True, True]
oys = [True, False, True, False, True, False]

for lT, wT, nT,dT,oxT,oyT in zip(ls, ws, ns,ds, oxs,oys):
    print(wT); rad = math.radians(wT); sin = math.sin(rad); cos = math.cos(rad)
    j1  = sin;j2  = cos; J  = [j1,j2]
    it = 50; L = 6; 
    trained_params_list   = []; parameters_list = [];iii = [] 
    g,hi,op = conf(J,L)
    exact_energy, exact_state = exac_calc_lanczos_ed(op)
    g_jt, jt_out  = calc_jastrow(g, hi, op, L,it)
    g_fn, fn_out  = calc_ffnn(hi,g,model,op, L, J, it)
    g_nfn,nfn_out = calc_nffnn(hi,g,model,op, L, J, it)
    g_rb, rb_out  = calc_rbm(hi,g,op,L,J,it)
    files = []; files.append(jt_out);files.append(fn_out);
    files.append(nfn_out);files.append(rb_out);

    plot(float(exact_energy),files,lT,wT, L,it, 
             float(g_jt.energy.mean.real),   
             float(g_fn.energy.mean.real),
             float(g_nfn.energy.mean.real),  
             float(g_rb.energy.mean), 
             oxT, oyT,-70,30, nT, dT)   
    print(exact_energy)
# Out:
# 270
# 50
# out/jastrow_6_-1_0_-1_8369701987210297e-16_50
# ---------------------
#   0%|                                                              | 0/50 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 16
#      14 g,hi,op = conf(J,L)
#      15 exact_energy, exact_state = exac_calc_lanczos_ed(op)
# ---> 16 g_jt, jt_out  = calc_jastrow(g, hi, op, L,it)
#      17 g_fn, fn_out  = calc_ffnn(hi,g,model,op, L, J, it)
#      18 g_nfn,nfn_out = calc_nffnn(hi,g,model,op, L, J, it)
#
# File /tmp/ipykernel_5794/1787399738.py:14, in calc_jastrow(g, hi, op, L, it)
#      12 print(v_out)
#      13 print("---------------------")
# ---> 14 gs.run(out=v_out, n_iter=it)
#      15 return gs,v_out
#
# File ~/work/nenv/lib/python3.11/site-packages/netket/driver/abstract_variational_driver.py:347, in AbstractVariationalDriver.run(self, n_iter, out, obs, step_size, show_progress, save_params_every, write_every, callback, timeit)
#     344 old_step = self.step_count
#     345 first_step = True
# --> 347 for step in self.iter(n_iter, step_size):
#     348     log_data = self.estimate(obs)
#     349     self._log_additional_data(log_data, step)
#
# File ~/work/nenv/lib/python3.11/site-packages/netket/driver/abstract_variational_driver.py:232, in AbstractVariationalDriver.iter(self, n_steps, step)
#     230 for _ in range(0, n_steps, step):
#     231     for i in range(0, step):
# --> 232         self._dp = self._forward_and_backward()
#     233         if i == 0:
#     234             yield self.step_count
#
#     [... skipping hidden 1 frame]
#
# File ~/work/nenv/lib/python3.11/site-packages/netket/driver/vmc.py:122, in VMC._forward_and_backward(self)
#     119 self.state.reset()
#     121 # Compute the local energy estimator and average Energy
# --> 122 self._loss_stats, self._loss_grad = self.state.expect_and_grad(self._ham)
#     124 # if it's the identity it does
#     125 # self._dp = self._loss_grad
#     126 self._dp = self.preconditioner(self.state, self._loss_grad, self.step_count)
#
#     [... skipping hidden 1 frame]
#
# File ~/work/nenv/lib/python3.11/site-packages/netket/vqs/mc/mc_state/state.py:692, in MCState.expect_and_grad(self, O, mutable, **kwargs)
#     689 if mutable is None:
#     690     mutable = self.mutable
# --> 692 return expect_and_grad(
#     693     self,
#     694     O,
#     695     self.chunk_size,
#     696     mutable=mutable,
#     697     **kwargs,
#     698 )
#
#     [... skipping hidden 1 frame]
#
# File ~/work/nenv/lib/python3.11/site-packages/netket/vqs/mc/mc_state/expect_grad.py:58, in expect_and_grad_default_formula(vstate, Ô, chunk_size, mutable, use_covariance, *args)
#      51     use_covariance = Ô.is_hermitian
#      53 if use_covariance:
#      54     # Implementation of expect_and_grad for `use_covariance == True` (due to the Literal[True]
#      55     # type in the signature).` This case is equivalent to the composition of the
#      56     # `expect_and_forces` and `force_to_grad` functions.
#      57     # return expect_and_grad_from_covariance(vstate, Ô, *args, mutable=mutable)
# ---> 58     Ō, Ō_grad = expect_and_forces(vstate, Ô, chunk_size, *args, mutable=mutable)
#      59     Ō_grad = force_to_grad(Ō_grad, vstate.parameters)
#      60     return Ō, Ō_grad
#
#     [... skipping hidden 1 frame]
#
# File ~/work/nenv/lib/python3.11/site-packages/netket/vqs/mc/mc_state/expect_forces.py:48, in expect_and_forces(vstate, Ô, chunk_size, mutable)
#      40 @dispatch
#      41 def expect_and_forces(  # noqa: F811
#      42     vstate: MCState,
#    (...)     46     mutable: CollectionFilter = False,
#      47 ) -> tuple[Stats, PyTree]:
# ---> 48     σ, args = get_local_kernel_arguments(vstate, Ô)
#      50     local_estimator_fun = get_local_kernel(vstate, Ô)
#      52     Ō, Ō_grad, new_model_state = forces_expect_hermitian(
#      53         local_estimator_fun,
#      54         vstate._apply_fun,
#    (...)     59         args,
#      60     )
#
#     [... skipping hidden 1 frame]
#
# File ~/work/nenv/lib/python3.11/site-packages/netket/vqs/mc/mc_state/expect.py:62, in get_local_kernel_arguments(vstate, Ô)
#      59 check_hilbert(vstate.hilbert, Ô.hilbert)
#      61 σ = vstate.samples
# ---> 62 σp, mels = Ô.get_conn_padded(σ)
#      63 return σ, (σp, mels)
#
# File ~/work/nenv/lib/python3.11/site-packages/netket/operator/_discrete_operator.py:83, in DiscreteOperator.get_conn_padded(self, x)
#      77 x_primes, mels = self.get_conn_flattened(
#      78     x.reshape(-1, x.shape[-1]), sections, pad=True
#      79 )
#      81 n_primes = sections[0]
# ---> 83 x_primes_r = x_primes.reshape(*x.shape[:-1], n_primes, n_visible)
#      84 mels_r = mels.reshape(*x.shape[:-1], n_primes)
#      86 return x_primes_r, mels_r
#
# File ~/work/nenv/lib/python3.11/site-packages/jax/_src/array.py:260, in ArrayImpl.shape(self)
#     257   addressable_da = sharding._addressable_device_assignment
#     258   return [device_id_to_buffer[device.id] for device in addressable_da]
# --> 260 @property
#     261 def shape(self) -> Shape:
#     262   return self.aval.shape
#     264 @property
#     265 def dtype(self):
#
# KeyboardInterrupt:

# %%
ls  = ['(a)','(b)']  
ws  = [270,300,315,330,340,0]

ws  = [270,300]
ns  = [30,30]
ds  = [20,18]
oxs = [False, True]
oys = [True, True,]


for lT, wT, nT,dT,oxT,oyT in zip(ls, ws, ns,ds, oxs,oys):
    print(wT); rad = math.radians(wT); sin = math.sin(rad); cos = math.cos(rad)
    j1  = sin;j2  = cos; J  = [j1,j2]
    it = 50; L = 6; 
    trained_params_list   = []; parameters_list = [];iii = [] 
    g,hi,op = conf(J,L)
    exact_energy, exact_state = exac_calc_lanczos_ed(op)
    g_jt, jt_out  = calc_jastrow(g, hi, op, L,it)
    g_fn, fn_out  = calc_ffnn(hi,g,model,op, L, J, it)
    g_nfn,nfn_out = calc_nffnn(hi,g,model,op, L, J, it)
    g_rb, rb_out  = calc_rbm(hi,g,op,L,J,it)
    files = []; files.append(jt_out);files.append(fn_out);
    files.append(nfn_out);files.append(rb_out);

    plot(float(exact_energy),files,lT,wT, L,it, 
             float(g_jt.energy.mean.real),   
             float(g_fn.energy.mean.real),
             float(g_nfn.energy.mean.real),  
             float(g_rb.energy.mean), 
             oxT, oyT,-70,30, nT, dT)   
    print(exact_energy)
# Out:
# 270
# 50
# out/jastrow_6_-1_0_-1_8369701987210297e-16_50
# ---------------------
#   0%|                                                              | 0/50 [00:00<?, ?it/s]
# 50
# out/ffnn6_-1_0_-1_8369701987210297e-16_50
# ---------------------
#   0%|                                                              | 0/50 [00:00<?, ?it/s]
#   0%|                                                              | 0/50 [00:00<?, ?it/s]
# 50
#   0%|                                                              | 0/50 [00:00<?, ?it/s]
# ---------------------------
# [-6.]
# 300
# 50
# out/jastrow_6_-0_8660254037844386_0_5000000000000001_50
# ---------------------
#   0%|                                                              | 0/50 [00:00<?, ?it/s]
# 50
# out/ffnn6_-0_8660254037844386_0_5000000000000001_50
# ---------------------
#   0%|                                                              | 0/50 [00:00<?, ?it/s]
#   0%|                                                              | 0/50 [00:00<?, ?it/s]
# 50
#   0%|                                                              | 0/50 [00:00<?, ?it/s]
# ---------------------------
# [-5.43403946]

# %%
ls  = ['(a)','(b)','(c)','(d)','(e)','(f)']
ws  = [0,120,240,300,180,60]
ns  = [0,2,4,5,1,1]
ds  = [0,3,3,3,1,3]
oxs = [False, False, False, False, True, True]
oys = [True, False, True, False, True, False]

# %%
for lT, wT, nT,dT,oxT,oyT in zip(ls, ws, ns,ds, oxs,oys):
    print(wT); rad = math.radians(wT); sin = math.sin(rad); cos = math.cos(rad)
    j1  = sin;j2  = cos; J  = [j1,j2]
    it = 300; L = 20; 
    trained_params_list   = []; parameters_list = [];iii = [] 
    g,hi,op = conf(J,L)
    exact_energy, exact_state = exac_calc_lanczos_ed(op)
    g_jt, jt_out  = calc_jastrow(g, hi, op, L,it)
    g_fn, fn_out  = calc_ffnn(hi,g,model,op, L, J, it)
    g_nfn,nfn_out = calc_nffnn(hi,g,model,op, L, J, it)
    g_rb, rb_out  = calc_rbm(hi,g,op,L,J,it)
    files = []; files.append(jt_out);files.append(fn_out);
    files.append(nfn_out);files.append(rb_out);

    plot(float(exact_energy),files,lT,wT, L,it, 
             float(g_jt.energy.mean.real),   
             float(g_fn.energy.mean.real),
             float(g_nfn.energy.mean.real),  
             float(g_rb.energy.mean), 
             oxT, oyT,-70,30, nT, dT)   
    print(exact_energy)
# Out:
# 0
# 300
# out/jastrow_20_0_0_1_0_300
# ---------------------
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# 300
# out/ffnn20_0_0_1_0_300
# ---------------------
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# 300
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# ---------------------------
# [-36.12357084]
# 120
# 300
# out/jastrow_20_0_8660254037844387_-0_4999999999999998_300
# ---------------------
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# 300
# out/ffnn20_0_8660254037844387_-0_4999999999999998_300
# ---------------------
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# 300
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# ---------------------------
# [-38.80465934]
# 240
# 300
# out/jastrow_20_-0_8660254037844384_-0_5000000000000004_300
# ---------------------
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# 300
# out/ffnn20_-0_8660254037844384_-0_5000000000000004_300
# ---------------------
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# 300
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# ---------------------------
# [-27.32050808]
# 300
# 300
# out/jastrow_20_-0_8660254037844386_0_5000000000000001_300
# ---------------------
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# 300
# out/ffnn20_-0_8660254037844386_0_5000000000000001_300
# ---------------------
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# 300
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# ---------------------------
# [-19.43419949]
# 180
# 300
# out/jastrow_20_1_2246467991473532e-16_-1_0_300
# ---------------------
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# 300
# out/ffnn20_1_2246467991473532e-16_-1_0_300
# ---------------------
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# 300
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# ---------------------------
# [-20.]
# 60
# 300
# out/jastrow_20_0_8660254037844386_0_5000000000000001_300
# ---------------------
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# 300
# out/ffnn20_0_8660254037844386_0_5000000000000001_300
# ---------------------
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# 300
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# ---------------------------
# [-26.22309167]

# %%
for lT, wT, nT,dT,oxT,oyT in zip(ls, ws, ns,ds, oxs,oys):
    print(wT); rad = math.radians(wT); sin = math.sin(rad); cos = math.cos(rad)
    j1  = sin;j2  = cos; J  = [j1,j2]
    it = 100; L = 20; 
    trained_params_list   = []; parameters_list = [];iii = [] 
    g,hi,op = conf(J,L)
    exact_energy, exact_state = exac_calc_lanczos_ed(op)
    g_jt, jt_out  = calc_jastrow(g, hi, op, L,it)
    g_fn, fn_out  = calc_ffnn(hi,g,model,op, L, J, it)
    g_nfn,nfn_out = calc_nffnn(hi,g,model,op, L, J, it)
    g_rb, rb_out  = calc_rbm(hi,g,op,L,J,it)
    files = []; files.append(jt_out);files.append(fn_out);
    files.append(nfn_out);files.append(rb_out);

    plot(float(exact_energy),files,lT,wT, L,it, 
             float(g_jt.energy.mean.real),   
             float(g_fn.energy.mean.real),
             float(g_nfn.energy.mean.real),  
             float(g_rb.energy.mean), 
             oxT, oyT,-70,30, nT, dT)   
    print(exact_energy)
# Out:
# 0
# 100
# out/jastrow_20_0_0_1_0_100
# ---------------------
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# 100
# out/ffnn20_0_0_1_0_100
# ---------------------
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# 100
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# ---------------------------
# [-36.12357084]
# 120
# 100
# out/jastrow_20_0_8660254037844387_-0_4999999999999998_100
# ---------------------
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# 100
# out/ffnn20_0_8660254037844387_-0_4999999999999998_100
# ---------------------
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# 100
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# ---------------------------
# [-38.80465934]
# 240
# 100
# out/jastrow_20_-0_8660254037844384_-0_5000000000000004_100
# ---------------------
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# 100
# out/ffnn20_-0_8660254037844384_-0_5000000000000004_100
# ---------------------
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# 100
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# ---------------------------
# [-27.32050808]
# 300
# 100
# out/jastrow_20_-0_8660254037844386_0_5000000000000001_100
# ---------------------
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# 100
# out/ffnn20_-0_8660254037844386_0_5000000000000001_100
# ---------------------
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# 100
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# ---------------------------
# [-19.43419949]
# 180
# 100
# out/jastrow_20_1_2246467991473532e-16_-1_0_100
# ---------------------
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# 100
# out/ffnn20_1_2246467991473532e-16_-1_0_100
# ---------------------
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# 100
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# ---------------------------
# [-20.]
# 60
# 100
# out/jastrow_20_0_8660254037844386_0_5000000000000001_100
# ---------------------
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# 100
# out/ffnn20_0_8660254037844386_0_5000000000000001_100
# ---------------------
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# 100
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# ---------------------------
# [-26.22309167]

# %%
plot(float(exact_energy),files,lT,wT, L,it, 
             float(g_jt.energy.mean.real),   
             float(g_fn.energy.mean.real),
             float(g_nfn.energy.mean.real),  
             float(g_rb.energy.mean), 
             oxT, oyT,-70,30, nT, dT)   
print(exact_energy)
# Out:
# ---------------------------
# [-36.12357084]

# %%
# %run 0_config.ipynb

# %%
for lT, wT, nT,dT,oxT,oyT in zip(ls, ws, ns,ds, oxs,oys):
    print(wT); rad = math.radians(wT); sin = math.sin(rad); cos = math.cos(rad)
    j1  = sin;j2  = cos; J  = [j1,j2]
    it = 100; L = 20; 
    trained_params_list   = []; parameters_list = [];iii = [] 
    g,hi,op = conf(J,L)
    exact_energy, exact_state = exac_calc_lanczos_ed(op)
    g_jt, jt_out  = calc_jastrow(g, hi, op, L,it)
    g_fn, fn_out  = calc_ffnn(hi,g,model,op, L, J, it)
    g_nfn,nfn_out = calc_nffnn(hi,g,model,op, L, J, it)
    g_rb, rb_out  = calc_rbm(hi,g,op,L,J,it)
    files = []; files.append(jt_out);files.append(fn_out);
    files.append(nfn_out);files.append(rb_out);

    plot(float(exact_energy),files,lT,wT, L,it, 
             float(g_jt.energy.mean.real),   
             float(g_fn.energy.mean.real),
             float(g_nfn.energy.mean.real),  
             float(g_rb.energy.mean), 
             oxT, oyT,-70,30, nT, dT)   
    print(exact_energy)

# %%
for lT, wT, nT,dT,oxT,oyT in zip(ls, ws, ns,ds, oxs,oys):
    print(wT); rad = math.radians(wT); sin = math.sin(rad); cos = math.cos(rad)
    j1  = sin;j2  = cos; J  = [j1,j2]
    it = 100; L = 20; 
    trained_params_list   = []; parameters_list = [];iii = [] 
    g,hi,op = conf(J,L)
    exact_energy, exact_state = exac_calc_lanczos_ed(op)
    g_jt, jt_out  = calc_jastrow(g, hi, op, L,it)
    g_fn, fn_out  = calc_ffnn(hi,g,model,op, L, J, it)
    g_nfn,nfn_out = calc_nffnn(hi,g,model,op, L, J, it)
    g_rb, rb_out  = calc_rbm(hi,g,op,L,J,it)
    files = []; files.append(jt_out);files.append(fn_out);
    files.append(nfn_out);files.append(rb_out);

    plot(float(exact_energy),files,lT,wT, L,it, 
             float(g_jt.energy.mean.real),   
             float(g_fn.energy.mean.real),
             float(g_nfn.energy.mean.real),  
             float(g_rb.energy.mean), 
             oxT, oyT,-70,30, nT, dT)   
    print(exact_energy)

# %%
w = 60; print(w); rad = math.radians(w); sin = math.sin(rad); cos = math.cos(rad)
j1  = sin;j2  = cos; J  = [j1,j2]
it = 300; L = 12; 
trained_params_list   = []; parameters_list = [];iii = [] 
g,hi,op = conf(J,L)
exact_energy, exact_state = exac_calc_lanczos_ed(op)
g_jt, jt_out  = calc_jastrow(g, hi, op, L,it)
g_fn, fn_out  = calc_ffnn(hi,g,model,op, L, J, it)
g_nfn,nfn_out = calc_nffnn(hi,g,model,op, L, J, it)
g_rb, rb_out  = calc_rbm(hi,g,op,L,J,it)
files = []; files.append(jt_out);files.append(fn_out);
files.append(nfn_out);files.append(rb_out);
# Out:
# 60
# 300
# out/jastrow_12_0_8660254037844386_0_5000000000000001_300
# ---------------------
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# 300
# out/ffnn12_0_8660254037844386_0_5000000000000001_300
# ---------------------
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# 300
#   0%|                                                             | 0/300 [00:00<?, ?it/s]

# %%
plot(float(exact_energy),files,"(d)",w, L,it, 
             float(g_jt.energy.mean.real),   
             float(g_fn.energy.mean.real),
             float(g_nfn.energy.mean.real),  
             float(g_rb.energy.mean), 
             True, False,-40,20, 1, 3)
# Out:
# ---------------------------

# %%
def plotws():
    ws = [0,120,240,300,180,60]
    wn = [0,2,4,5,1,1]
    wd = [0,3,3,3,1,3]

    for w, n, d in zip(ws, wn, wd):
        print(f"ws = {w}, wn = {n}, wd = {d}")
        print(w)
        
        print(w); rad = math.radians(w); sin = math.sin(rad); cos = math.cos(rad)
        j1  = sin;j2  = cos; J  = [j1,j2]
        it = 200; L = 12; 
        trained_params_list   = []; parameters_list = [];iii = [] 
        g,hi,op = conf(J,L)
        exact_energy, exact_state = exac_calc_lanczos_ed(op)
        g_jt, jt_out  = calc_jastrow(g, hi, op, L,it)
        g_fn, fn_out  = calc_ffnn(hi,g,model,op, L, J, it)
        g_nfn,nfn_out = calc_nffnn(hi,g,model,op, L, J, it)
        g_rb, rb_out  = calc_rbm(hi,g,op,L,J,it)
        files = []; files.append(jt_out);files.append(fn_out);
        files.append(nfn_out);files.append(rb_out);
        plot(float(exact_energy),files,"(a)",12, L,it, 
             float(g_jt.energy.mean.real),   
             float(g_fn.energy.mean.real),
             float(g_nfn.energy.mean.real),  
             float(g_rb.energy.mean), 
             False, True,0, 0, 
             wn, wd)

# %%
plotws()
# Out:
# ws = 0, wn = 0, wd = 0
# 0
# 0
# 200
# out/jastrow_12_0_25881904510252074_0_9659258262890683_200
# ---------------------
#   0%|                                                                                                         …
# 200
# out/ffnn12_0_0_1_0_200
# ---------------------
#   0%|                                                                                                         …
#   0%|                                                                                                         …
# 200
#   0%|                                                                                                         …
# ---------------------------
# ws = 120, wn = 2, wd = 3
# 120
# 120
# 200
# out/jastrow_12_0_25881904510252074_0_9659258262890683_200
# ---------------------
#   0%|                                                                                                         …
# 200
# out/ffnn12_0_8660254037844387_-0_4999999999999998_200
# ---------------------
#   0%|                                                                                                         …
#   0%|                                                                                                         …
# 200
#   0%|                                                                                                         …
# ---------------------------
# ws = 240, wn = 4, wd = 3
# 240
# 240
# 200
# out/jastrow_12_0_25881904510252074_0_9659258262890683_200
# ---------------------
#   0%|                                                                                                         …
# 200
# out/ffnn12_-0_8660254037844384_-0_5000000000000004_200
# ---------------------
#   0%|                                                                                                         …
#   0%|                                                                                                         …
# 200
#   0%|                                                                                                         …
# ---------------------------
# ws = 300, wn = 5, wd = 3
# 300
# 300
# 200
# out/jastrow_12_0_25881904510252074_0_9659258262890683_200
# ---------------------
#   0%|                                                                                                         …
# 200
# out/ffnn12_-0_8660254037844386_0_5000000000000001_200
# ---------------------
#   0%|                                                                                                         …
#   0%|                                                                                                         …
# 200
#   0%|                                                                                                         …
# ---------------------------
# ws = 180, wn = 1, wd = 1
# 180
# 180
# 200
# out/jastrow_12_0_25881904510252074_0_9659258262890683_200
# ---------------------
#   0%|                                                                                                         …
# 200
# out/ffnn12_1_2246467991473532e-16_-1_0_200
# ---------------------
#   0%|                                                                                                         …

# %%
plot(float(exact_energy),files,"(a)",12, L,it, 
     float(g_jt.energy.mean.real),   
     float(g_fn.energy.mean.real),
     float(g_nfn.energy.mean.real),  
     float(g_rb.energy.mean), 
     False, True,0, 0, 
     1, 3)
# Out:
# ---------------------------

# %%
w = 15; print(w); rad = math.radians(w); sin = math.sin(rad); cos = math.cos(rad)
j1  = sin;j2  = cos; J  = [j1,j2]
it = 200; L = 12; 
trained_params_list   = []; parameters_list = [];iii = [] 
g,hi,op = conf(J,L)
exact_energy, exact_state = exac_calc_lanczos_ed(op)
g_jt, jt_out  = calc_jastrow(g, hi, op, L,it)
g_fn, fn_out  = calc_ffnn(hi,g,model,op, L, J, it)
g_nfn,nfn_out = calc_nffnn(hi,g,model,op, L, J, it)
g_rb, rb_out  = calc_rbm(hi,g,op,L,J,it)
files = []; files.append(jt_out);files.append(fn_out);
files.append(nfn_out);files.append(rb_out);
# Out:
# 15
# 200
# out/jastrow_12_0_25881904510252074_0_9659258262890683_200
# ---------------------
#   0%|                                                                                                         …
# 200
# out/ffnn12_0_25881904510252074_0_9659258262890683_200
# ---------------------
#   0%|                                                                                                         …
#   0%|                                                                                                         …
# 200
#   0%|                                                                                                         …

# %%
plot(float(exact_energy),files,"(a)",12, L,it, 
     float(g_jt.energy.mean.real),   
     float(g_fn.energy.mean.real),
     float(g_nfn.energy.mean.real),  
     float(g_rb.energy.mean), 
     False, True,0, 0)
# Out:
# ---------------------------

# %%
# Out:
# ---------------------------

# %%
# Out:
# 50
# out/jastrow_12_1_0_2_50
# ---------------------
#   0%|                                                                                                         …
# 50
# out/ffnn12_1_0_2_50
# ---------------------
#   0%|                                                                                                         …
#   0%|                                                                                                         …
# 50
#   0%|                                                                                                         …
# out/jastrow_12_1_0_2_50.log
# out/ffnn12_1_0_2_50.log
# out/nffnn12_1_0_2_50.log
# out/rbm12_1_0_2_50.log
# ---------------------------

# %%
g_jt, jt_out  = calc_jastrow(g, hi, op, L,it)
# Out:
# 50
# out/jastrow_12_1_0_2_50
# ---------------------
#   0%|                                                              | 0/50 [00:00<?, ?it/s]

# %%
g_fn, fn_out  = calc_ffnn(hi,g,model,op, L, J, it)
# Out:
# 50
#   0%|                                                              | 0/50 [00:00<?, ?it/s]

# %%
g_rb, rb_out  = calc_rbm(hi,g,op,L,J,it)
# Out:
# 50
#   0%|                                                              | 0/50 [00:00<?, ?it/s]

# %%
rb_out
# Out:
# 'out/rbm12_1_0_2_50'

# %%
jt_out
# Out:
# 'out/jastrow_12_1_0_2_50'

# %%
it = 50; L = 12; J = [1,0.2]
trained_params_list   = []; parameters_list = [];iii = [] 
g,hi,op = conf(J,L)
exact_energy, exact_state = exac_calc_lanczos_ed(op)
g_jt, jt_out  = calc_jastrow(g, hi, op, L,it)
g_fn, fn_out  = calc_ffnn(hi,g,model,op, L, J, it)
files = []; files.append(jt_out);files.append(fn_out);
# Out:
# 50
# out/jastrow_12_1_0_2_50
# ---------------------
#   0%|                                                              | 0/50 [00:00<?, ?it/s]
# 50
#   0%|                                                              | 0/50 [00:00<?, ?it/s]

# %%
g_nfn, nfn_out  = calc_nffnn(hi,g,model,op, L, J, it)
# Out:
#   0%|                                                              | 0/50 [00:00<?, ?it/s]

# %%
nfn_out
# Out:
# 'out/nffnn12_1_0_2_50'

# %%
jt_out,fn_out
# Out:
# ('out/jastrow_12_1_0_2_50', 'out/ffnn12_1_0_2_50')

# %%
files = []; files.append(jt_out);files.append(fn_out);
files.append(nfn_out);files.append(rb_out);

# %%
files
# Out:
# ['out/jastrow_12_1_0_2_50',
#  'out/ffnn12_1_0_2_50',
#  'out/nffnn12_1_0_2_50',
#  'out/rbm12_1_0_2_50']

# %%
float(g_rb.energy.mean)
# Out:
# -19.808990743163683

# %%
plot(float(exact_energy),files,"(a)",L,it, 
     float(g_jt.energy.mean.real),   
     float(g_fn.energy.mean.real),
     float(g_nfn.energy.mean.real),  
     float(g_rb.energy.mean), 
     True, True)
# Out:
# out/jastrow_12_1_0_2_50.log
# out/ffnn12_1_0_2_50.log
# out/nffnn12_1_0_2_50.log
# out/rbm12_1_0_2_50.log
# ---------------------------

# %%
# %run 0_config.ipynb

# %%
it = 50; L = 20; J = [1,0.2]
trained_params_list   = []; parameters_list = [];iii = [] 
g,hi,op = conf(J,L)
exact_energy, exact_state = exac_calc_lanczos_ed(op)
g_jt, jt_out  = calc_jastrow(g, hi, op, L,it)
g_fn, fn_out  = calc_ffnn(hi,g,model,op, L, J, it)
g_nfn,nfn_out = calc_nffnn(hi,g,model,op, L, J, it)
g_rb, rb_out  = calc_rbm(hi,g,op,L,J,it)
files = []; files.append(jt_out);files.append(fn_out);
files.append(nfn_out);files.append(rb_out);
# Out:
# 50
# out/jastrow_20_1_0_2_50
# ---------------------
#   0%|                                                              | 0/50 [00:00<?, ?it/s]
# 50
# out/ffnn20_1_0_2_50
# ---------------------
#   0%|                                                              | 0/50 [00:00<?, ?it/s]
#   0%|                                                              | 0/50 [00:00<?, ?it/s]
# 50
#   0%|                                                              | 0/50 [00:00<?, ?it/s]

# %%
exact_energy
# Out:
# array([-32.81166501])

# %%
plot(float(exact_energy),files,"(b)",L,it, 
     float(g_jt.energy.mean.real),   
     float(g_fn.energy.mean.real),
     float(g_nfn.energy.mean.real),  
     float(g_rb.energy.mean), 
     True, False)
# Out:
# out/jastrow_20_1_0_2_50.log
# out/ffnn20_1_0_2_50.log
# out/nffnn20_1_0_2_50.log
# out/rbm20_1_0_2_50.log
# ---------------------------

# %%
it = 50; L = 22; J = [1,0.2]
trained_params_list   = []; parameters_list = [];iii = [] 
g,hi,op = conf(J,L)
exact_energy, exact_state = exac_calc_lanczos_ed(op)
g_jt, jt_out  = calc_jastrow(g, hi, op, L,it)
g_fn, fn_out  = calc_ffnn(hi,g,model,op, L, J, it)
g_nfn,nfn_out = calc_nffnn(hi,g,model,op, L, J, it)
g_rb, rb_out  = calc_rbm(hi,g,op,L,J,it)
files = []; files.append(jt_out);files.append(fn_out);
files.append(nfn_out);files.append(rb_out);
plot(float(exact_energy),files,"(b)",L,it, 
     float(g_jt.energy.mean.real),   
     float(g_fn.energy.mean.real),
     float(g_nfn.energy.mean.real),  
     float(g_rb.energy.mean), 
     True, False)
# Out:
# 50
# out/jastrow_22_1_0_2_50
# ---------------------
#   0%|                                                              | 0/50 [00:00<?, ?it/s]
# 50
# out/ffnn22_1_0_2_50
# ---------------------
#   0%|                                                              | 0/50 [00:00<?, ?it/s]
#   0%|                                                              | 0/50 [00:00<?, ?it/s]
# 50
#   0%|                                                              | 0/50 [00:00<?, ?it/s]
# out/jastrow_22_1_0_2_50.log
# out/ffnn22_1_0_2_50.log
# out/nffnn22_1_0_2_50.log
# out/rbm22_1_0_2_50.log
# ---------------------------

# %%
it = 50; L = 14; J = [1,0.2]
trained_params_list   = []; parameters_list = [];iii = [] 
g,hi,op = conf(J,L)
exact_energy, exact_state = exac_calc_lanczos_ed(op)
g_jt, jt_out  = calc_jastrow(g, hi, op, L,it)
g_fn, fn_out  = calc_ffnn(hi,g,model,op, L, J, it)
g_nfn,nfn_out = calc_nffnn(hi,g,model,op, L, J, it)
g_rb, rb_out  = calc_rbm(hi,g,op,L,J,it)
files = []; files.append(jt_out);files.append(fn_out);
files.append(nfn_out);files.append(rb_out);
plot(float(exact_energy),files,"(b)",L,it, 
     float(g_jt.energy.mean.real),   
     float(g_fn.energy.mean.real),
     float(g_nfn.energy.mean.real),  
     float(g_rb.energy.mean), 
     True, False)
# Out:
# 50
# out/jastrow_14_1_0_2_50
# ---------------------
#   0%|                                                              | 0/50 [00:00<?, ?it/s]
# 50
# out/ffnn14_1_0_2_50
# ---------------------
#   0%|                                                              | 0/50 [00:00<?, ?it/s]
#   0%|                                                              | 0/50 [00:00<?, ?it/s]
# 50
#   0%|                                                              | 0/50 [00:00<?, ?it/s]
# out/jastrow_14_1_0_2_50.log
# out/ffnn14_1_0_2_50.log
# out/nffnn14_1_0_2_50.log
# out/rbm14_1_0_2_50.log
# ---------------------------

# %%
print(exact_energy)
# Out:
# [-19.99137154]

# %%
it = 400; L = 14; J = [0.721,0.721]
trained_params_list   = []; parameters_list = [];iii = [] 
g,hi,op = conf(J,L)
exact_energy, exact_state = exac_calc_lanczos_ed(op)
g_jt, jt_out  = calc_jastrow(g, hi, op, L,it)
g_fn, fn_out  = calc_ffnn(hi,g,model,op, L, J, it)
g_nfn,nfn_out = calc_nffnn(hi,g,model,op, L, J, it)
g_rb, rb_out  = calc_rbm(hi,g,op,L,J,it)
files = []; files.append(jt_out);files.append(fn_out);
print(exact_energy)
files.append(nfn_out);files.append(rb_out);
plot(float(exact_energy),files,"(b)",L,it, 
     float(g_jt.energy.mean.real),   
     float(g_fn.energy.mean.real),
     float(g_nfn.energy.mean.real),  
     float(g_rb.energy.mean), 
     True, False)
# Out:
# 400
# out/jastrow_14_0_721_0_721_400
# ---------------------
#   0%|                                                             | 0/400 [00:00<?, ?it/s]
# 400
# out/ffnn14_0_721_0_721_400
# ---------------------
#   0%|                                                             | 0/400 [00:00<?, ?it/s]
#   0%|                                                             | 0/400 [00:00<?, ?it/s]
# 400
#   0%|                                                             | 0/400 [00:00<?, ?it/s]
# [-19.99137154]
# out/jastrow_14_0_721_0_721_400.log
# out/ffnn14_0_721_0_721_400.log
# out/nffnn14_0_721_0_721_400.log
# out/rbm14_0_721_0_721_400.log
# ---------------------------

# %%
it = 150; L = 14; J = [0.85,0.5]
trained_params_list   = []; parameters_list = [];iii = [] 
g,hi,op = conf(J,L)
exact_energy, exact_state = exac_calc_lanczos_ed(op)
g_jt, jt_out  = calc_jastrow(g, hi, op, L,it)
g_fn, fn_out  = calc_ffnn(hi,g,model,op, L, J, it)
g_nfn,nfn_out = calc_nffnn(hi,g,model,op, L, J, it)
g_rb, rb_out  = calc_rbm(hi,g,op,L,J,it)
files = []; files.append(jt_out);files.append(fn_out);
print(exact_energy)
files.append(nfn_out);files.append(rb_out);
plot(float(exact_energy),files,"(b)",L,it, 
     float(g_jt.energy.mean.real),   
     float(g_fn.energy.mean.real),
     float(g_nfn.energy.mean.real),  
     float(g_rb.energy.mean), 
     True, False)
# Out:
# 150
# out/jastrow_14_0_85_0_5_150
# ---------------------
#   0%|                                                             | 0/150 [00:00<?, ?it/s]
# 150
# out/ffnn14_0_85_0_5_150
# ---------------------
#   0%|                                                             | 0/150 [00:00<?, ?it/s]
#   0%|                                                             | 0/150 [00:00<?, ?it/s]
# 150
#   0%|                                                             | 0/150 [00:00<?, ?it/s]
# [-18.09187695]
# out/jastrow_14_0_85_0_5_150.log
# out/ffnn14_0_85_0_5_150.log
# out/nffnn14_0_85_0_5_150.log
# out/rbm14_0_85_0_5_150.log
# ---------------------------

# %%
plot(float(exact_energy),files,"(b)",L,it, 
     float(g_jt.energy.mean.real),   
     float(g_fn.energy.mean.real),
     float(g_nfn.energy.mean.real),  
     float(g_rb.energy.mean), 
     True, False)
# Out:
# out/jastrow_14_0_85_0_5_150.log
# out/ffnn14_0_85_0_5_150.log
# out/nffnn14_0_85_0_5_150.log
# out/rbm14_0_85_0_5_150.log
# ---------------------------

# %%
# %run 0_config.ipynb
