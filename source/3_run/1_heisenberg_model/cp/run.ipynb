# %%
def run(L1,IT,TFe):
    net = 'ffnn_i'

    # %run 0_config_plot.ipynb
    # %run 0_config_nets.ipynb

    it = IT; tFe = TFe
    for ll in L1:
        print(ll)
        L = ll
    
        trained_params_list              = []; parameters_list = [];iii = []; 
        g_run_cc_energy1,r_out1, paths1  = run_net (tFe,L,it,True,1, net)  

        exact_gs_energy1,e_path1         = exac_calc_lanczos_ed(tFe,L, True)
        calc_j_gs_energy1,j_out1         = jastrow_calc(tFe,L,it,True)

    str_nets = '1_' + net.upper(); l_info = []; l_info.append(net.upper())
    l_tp   = []
    l_tp.append('Ferromagnetismo')
    L  = ll
    x_pos  = 0.2 ;  y_pos = 0.94; index = 2
    # %run 0_config_plot.ipynb
    plot1(e_path1,j_out1, r_out1, L, it,l_info,l_tp,x_pos, y_pos, str_nets)

# %%
L1     = [20]; IT =300; TFe = 0
run(L1,IT,TFe)
# Out:
# 20
# ffnn_i
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# fig/w/EGS_L_20_IT_300_1_FFNN_I.png

# %%
L1     = [8]
net = 'ffnn_i'

# %run 0_config_plot.ipynb
# %run 0_config_nets.ipynb

it = 300; tFe = 0
for ll in L1:
    print(ll)
    L = ll
    
    trained_params_list              = []; parameters_list = [];iii = []; 
    g_run_cc_energy1,r_out1, paths1  = run_net (tFe,L,it,True,1, net)  

    exact_gs_energy1,e_path1         = exac_calc_lanczos_ed(tFe,L, True)
    calc_j_gs_energy1,j_out1         = jastrow_calc(tFe,L,it,True)

str_nets = '1_' + net.upper(); l_info = []; l_info.append(net.upper())
l_tp   = []
l_tp.append('Ferromagnetismo')
L  = ll
x_pos  = 0.2 ;  y_pos = 0.94; index = 2
# %run 0_config_plot.ipynb
plot1(e_path1,j_out1, r_out1, L, it,l_info,l_tp,x_pos, y_pos, str_nets)
# Out:
# 8
# ffnn_i
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# fig/w/EGS_L_8_IT_300_1_FFNN_I.png

# %%
L1     = [8]
net = 'ffnn_i'



# %run 0_config_plot.ipynb
# %run 0_config_nets.ipynb

it = 300; tFe = 0
for ll in L1:
    print(ll)
    L = ll
    
    trained_params_list              = []; parameters_list = [];iii = []; 
    g_run_cc_energy1,r_out1, paths1  = run_net (tFe,L,it,True,1, net)  

    exact_gs_energy1,e_path1         = exac_calc_lanczos_ed(tFe,L, True)
    calc_j_gs_energy1,j_out1         = jastrow_calc(tFe,L,it,True)

str_nets = '1_' + net.upper(); l_info = []; l_info.append(net.upper())
l_tp   = []
l_tp.append('Ferromagnetismo')
L  = ll
x_pos  = 0.2 ;  y_pos = 0.94; index = 2
# %run 0_config_plot.ipynb
plot1(e_path1,j_out1, r_out1, L, it,l_info,l_tp,x_pos, y_pos, str_nets)
# Out:
# 8
# ffnn_i
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# fig/w/EGS_L_8_IT_300_1_FFNN_I.png

# %%
L1     = [12]
net = 'ffnn_i'



# %run 0_config_plot.ipynb
# %run 0_config_nets.ipynb

it = 300; tFe = 0
for ll in L1:
    print(ll)
    L = ll
    
    trained_params_list              = []; parameters_list = [];iii = []; 
    g_run_cc_energy1,r_out1, paths1  = run_net (tFe,L,it,True,1, net)  

    exact_gs_energy1,e_path1         = exac_calc_lanczos_ed(tFe,L, True)
    calc_j_gs_energy1,j_out1         = jastrow_calc(tFe,L,it,True)

str_nets = '1_' + net.upper(); l_info = []; l_info.append(net.upper())
l_tp   = []
l_tp.append('Ferromagnetismo')
L  = ll
x_pos  = 0.2 ;  y_pos = 0.94; index = 2
# %run 0_config_plot.ipynb
plot1(e_path1,j_out1, r_out1, L, it,l_info,l_tp,x_pos, y_pos, str_nets)
# Out:
# 12
# ffnn_i
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# fig/w/EGS_L_12_IT_300_1_FFNN_I.png

# %%
L1     = [4]
net = 'ffnn_i'
# %run 0_config_plot.ipynb
# %run 0_config_nets.ipynb

it = 120; tFe = 0
for ll in L1:
    print(ll)
    L = ll
    
    trained_params_list              = []; parameters_list = [];iii = []; 
    g_run_cc_energy1,r_out1, paths1  = run_net (tFe,L,it,True,1, net)  

    exact_gs_energy1,e_path1         = exac_calc_lanczos_ed(tFe,L, True)
    calc_j_gs_energy1,j_out1         = jastrow_calc(tFe,L,it,True)

str_nets = '1_' + net.upper(); l_info = []; l_info.append(net.upper())
l_tp   = []
l_tp.append('Ferromagnetismo')
L  = ll
x_pos  = 0.2 ;  y_pos = 0.94; index = 2
# %run 0_config_plot.ipynb
plot1(e_path1,j_out1, r_out1, L, it,l_info,l_tp,x_pos, y_pos, str_nets)

# %%
L1     = [4]

# %%
net = 'ffnn_i'

# %%
# %run 0_config_plot.ipynb
# %run 0_config_nets.ipynb

it = 120; tFe = 0
for ll in L1:
    print(ll)
    L = ll
    
    trained_params_list              = []; parameters_list = [];iii = []; 
    g_run_cc_energy1,r_out1, paths1  = run_net (tFe,L,it,True,1, net)  

    exact_gs_energy1,e_path1         = exac_calc_lanczos_ed(tFe,L, True)
    calc_j_gs_energy1,j_out1         = jastrow_calc(tFe,L,it,True)

str_nets = '1_' + net.upper(); l_info = []; l_info.append(net.upper())
l_tp   = []
l_tp.append('Ferromagnetismo')
L  = ll
x_pos  = 0.2 ;  y_pos = 0.94; index = 2
# %run 0_config_plot.ipynb
plot1(e_path1,j_out1, r_out1, L, it,l_info,l_tp,x_pos, y_pos, str_nets)
# Out:
# 4
# ffnn_i
#   0%|                                                             | 0/120 [00:00<?, ?it/s]
#   0%|                                                             | 0/120 [00:00<?, ?it/s]
# fig/w/EGS_L_4_IT_120_1_FFNN_I.png

# %%
net = 'ffnn'

# %%
# %run 0_config_plot.ipynb
# %run 0_config_nets.ipynb

it = 120; tFe = 0
for ll in L1:
    print(ll)
    L = ll
    
    trained_params_list              = []; parameters_list = [];iii = []; 
    g_run_cc_energy1,r_out1, paths1  = run_net (tFe,L,it,True,1, net)  

    exact_gs_energy1,e_path1         = exac_calc_lanczos_ed(tFe,L, True)
    calc_j_gs_energy1,j_out1         = jastrow_calc(tFe,L,it,True)

str_nets = '1_' + net.upper(); l_info = []; l_info.append(net.upper())
l_tp   = []
l_tp.append('Ferromagnetismo')
L  = ll
x_pos  = 0.2 ;  y_pos = 0.94; index = 2
# %run 0_config_plot.ipynb
plot1(e_path1,j_out1, r_out1, L, it,l_info,l_tp,x_pos, y_pos, str_nets)
# Out:
# 4
# ffnn
#   0%|                                                             | 0/120 [00:00<?, ?it/s]
#   0%|                                                             | 0/120 [00:00<?, ?it/s]
# fig/w/EGS_L_4_IT_120_1_FFNN.png

# %%
# %run 0_config_plot.ipynb
# %run 0_config_nets.ipynb

it = 120; tFe = 1
for ll in L1:
    print(ll)
    L = ll
    
    trained_params_list              = []; parameters_list = [];iii = []; 
    g_run_cc_energy1,r_out1, paths1  = run_net (tFe,L,it,True,1, net)  

    exact_gs_energy1,e_path1         = exac_calc_lanczos_ed(tFe,L, True)
    calc_j_gs_energy1,j_out1         = jastrow_calc(tFe,L,it,True)

str_nets = '1_' + net.upper(); l_info = []; l_info.append(net.upper())
l_tp   = []
l_tp.append('Fe')
L  = ll
x_pos  = 0.2 ;  y_pos = 0.94; index = 2
# %run 0_config_plot.ipynb
plot1(e_path1,j_out1, r_out1, L, it,l_info,l_tp,x_pos, y_pos, str_nets)
# Out:
# 4
# ffnn_i
#   0%|                                                             | 0/120 [00:00<?, ?it/s]
#   0%|                                                             | 0/120 [00:00<?, ?it/s]
# fig/w/EGS_L_4_IT_120_1_FFNN_I.png

# %%
L1     = [12]

# %%
net = 'rbm'

# %%
# %run 0_config_plot.ipynb
# %run 0_config_nets.ipynb

it = 50; tFe = 0
for ll in L1:
    print(ll)
    trained_params_list              = []; parameters_list = [];iii = []; 
    exact_gs_energy1,e_path1         = exac_calc_lanczos_ed(tFe,L, True)
    calc_j_gs_energy1,j_out1         = jastrow_calc(tFe,L,it,True)
    g_run_cc_energy1,r_out1, paths1  = run_net (tFe,L,it,True,1, net)  

str_nets = '1_RBM'; l_info = ['RBM']
l_tp   = ['Ferromagnético']; L      = ll
x_pos  = 0.2 ;  y_pos = 0.94; index = 2
# %run 0_config_plot.ipynb
plot1(e_path1,j_out1, r_out1, L, it,l_info,l_tp,x_pos, y_pos, str_nets)
# Out:
# 12
#   0%|                                                              | 0/50 [00:00<?, ?it/s]
#   0%|                                                              | 0/50 [00:00<?, ?it/s]
# fig/w/EGS_L_12_IT_50_1_RBM.png

# %%
# %run 0_config_plot.ipynb
# %run 0_config_nets.ipynb
L1 = [6]
it = 400; tFe = 0
net = 'ffnn'
for ll in L1:
    print(ll)
    L = ll
    trained_params_list              = []; parameters_list = [];iii = []; 
    g_run_cc_energy1,r_out1, paths1  = run_net (tFe,L,it,True,1, net)  

    exact_gs_energy1,e_path1         = exac_calc_lanczos_ed(tFe,L, True)
    calc_j_gs_energy1,j_out1         = jastrow_calc(tFe,L,it,True)

str_nets = '1_FFNN'; l_info = ['FFNN']
l_tp   = ['Ferromagnético']; L      = ll
x_pos  = 0.2 ;  y_pos = 0.94; index = 2
# %run 0_config_plot.ipynb
plot1(e_path1,j_out1, r_out1, ll, it,l_info,l_tp,x_pos, y_pos, str_nets)
# Out:
# 6
#   0%|                                                             | 0/400 [00:00<?, ?it/s]
#   0%|                                                             | 0/400 [00:00<?, ?it/s]
# fig/w/EGS_L_6_IT_400_1_FFNN.png

# %%
float(exact_gs_energy1), float(calc_j_gs_energy1), float(g_run_cc_energy1)
# Out:
# (-6.000000000000001, -5.984884367345488, -5.506477072676447)
