# %%
# %run 0_config.ipynb

# %%
L = 22; it=100; tFe = 1; trained_params_list = []; parameters_list = [];iii = []; x_axis = False
mens, exact_gs_energy = exac_calc_lanczos_ed(tFe,L, True)
calc_j_gs_energy,j_out = jastrow_calc(tFe,L,it,True)
# Out:
#   0%|                                                             | 0/100 [00:00<?, ?it/s]

# %%
g_run_cc_energy,r_out, paths = srbm(tFe,L,it,True,1)
# Out:
#   0%|                                                             | 0/100 [00:00<?, ?it/s]

# %%
paths
# Out:
# ['data/srbm_22_100_bias_real.csv',
#  'data/srbm_22_100_bias_img.csv',
#  'data/srbm_22_100_kernel_real.csv',
#  'data/srbm_22_100_kernel_img.csv']

# %%
# %run 0_config.ipynb

# %%
plots_n(paths, 0, -1)
# Out:
# ---------------------------
# Métricas Estatísticas:
# ----------------------
# Média da diferença: 0.00
# Desvio padrão da diferença: 0.44
# Tamanho do efeito (Cohen's d): 0.00
# Magnitude da diferença (norma L2): 2.00
# ---------------------------

# %%
L = 10; it = 600; trained_params_list = []; parameters_list = [];iii = [] 
g_run_cc_energy,r_out, paths = rbm_fe(0,L,it,True,4)
# Out:
#   0%|                                                             | 0/600 [00:00<?, ?it/s]

# %%
plots_n(paths, False, 0, -1)
# Out:
# Métricas Estatísticas:
# ----------------------
# Média da diferença: -0.01
# Desvio padrão da diferença: 0.16
# Tamanho do efeito (Cohen's d): -0.03
# Magnitude da diferença (norma L2): 3.22

# %%
L = 10; it = 600; trained_params_list = []; parameters_list = [];iii = [] 
g_run_cc_energy,r_out, paths = rbm(1,L,it,True,1)
# Out:
#   0%|                                                             | 0/600 [00:00<?, ?it/s]

# %%
plots_n(paths, False, 0, -1)
# Out:
# Métricas Estatísticas:
# ----------------------
# Média da diferença: -0.00
# Desvio padrão da diferença: 0.38
# Tamanho do efeito (Cohen's d): -0.00
# Magnitude da diferença (norma L2): 3.82

# %%
L = 8; it = 100; trained_params_list = []; parameters_list = [];iii = [] 
g_run_cc_energy,r_out, paths = rbm(1,L,it,True,3)
plots_n(paths, 0, -1)
# Out:
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# Métricas Estatísticas:
# ----------------------
# Média da diferença: 0.00
# Desvio padrão da diferença: 0.17
# Tamanho do efeito (Cohen's d): 0.00
# Magnitude da diferença (norma L2): 2.35

# %%
L = 8; it = 100; trained_params_list = []; parameters_list = [];iii = [] 
g_run_cc_energy,r_out, paths = rbm_fe(1,L,it,True,3)
plots_n(paths, 0, -1)
# Out:
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# Métricas Estatísticas:
# ----------------------
# Média da diferença: 0.01
# Desvio padrão da diferença: 0.24
# Tamanho do efeito (Cohen's d): 0.02
# Magnitude da diferença (norma L2): 3.34

# %%
L = 8; it = 100; trained_params_list = []; parameters_list = [];iii = [] 
g_run_cc_energy,r_out, paths = rbm_fe(1,L,it,True,3)
plots_n(paths, 0, -1)
# Out:
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# Métricas Estatísticas:
# ----------------------
# Média da diferença: 0.00
# Desvio padrão da diferença: 0.24
# Tamanho do efeito (Cohen's d): 0.01
# Magnitude da diferença (norma L2): 3.33

# %%
L = 8; it = 100; trained_params_list = []; parameters_list = [];iii = [] 
g_run_cc_energy,r_out, paths = rbm_fe(1,L,it,True,3)
plots_n(paths, 0, -1)
# Out:
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# Métricas Estatísticas:
# ----------------------
# Média da diferença: 0.00
# Desvio padrão da diferença: 0.24
# Tamanho do efeito (Cohen's d): 0.01
# Magnitude da diferença (norma L2): 3.29
