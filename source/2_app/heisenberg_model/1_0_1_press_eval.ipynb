# %%
# %run 0_config.ipynb

# %% [markdown]
# energy_text = (
#     "Métodos Variacionais\n"
#     f"{'Energia (Jastrow)':<20}: {e1:.4f}\n"
#     f"{'Energia (SRBM)'   :<20}: {e2:.4f}\n"
#     f"{'Energia (FFNN)'   :<20}: {e3:.4f}\n"
#     f"{'Energia (M-FFNN)' :<20}: {e4:.4f}\n"
#     "\nReferência\n"
#     f"{'Energia (Exata)'  :<20}: {e5:.4f}"
# )

# %%
def press(L, it, x_axis):
    tFe = 0; trained_params_list = []; parameters_list = [];iii = [] 
    mens, exact_gs_energy = exac_calc_lanczos_ed(tFe,L, True)
    calc_j_gs_energy,j_out = jastrow_calc(tFe,L,it,True)
    g_run_cc_energy,r_out, paths = rbm_fe(tFe,L,it,True,1)
    files = [] ; files.append(j_out);files.append(r_out);
    plot(exact_gs_energy,files,"(a)","RBM",L,tFe,it, 
         float(calc_j_gs_energy), float(g_run_cc_energy.energy.mean.real), float(exact_gs_energy),x_axis, True )

    tFe = 1
    mens, exact_gs_energy = exac_calc_lanczos_ed(tFe,L, True)
    calc_j_gs_energy,j_out = jastrow_calc(tFe,L,it,True)
    g_run_cc_energy,r_out, paths = rbm(tFe,L,it,True,1)
    files = [] ; files.append(j_out);files.append(r_out);
    plot(exact_gs_energy,files,"(b)","RBM",L,tFe,it,
         float(calc_j_gs_energy), float(g_run_cc_energy.energy.mean.real), float(exact_gs_energy),x_axis, False)

# %%
press(12,80, False)
# Out:
# ...
#   0%|                                                              | 0/80 [00:00<?, ?it/s]
# ---------------------------
# ...
#   0%|                                                              | 0/80 [00:00<?, ?it/s]
# ---------------------------

# %%
press(14,100)
# Out:
# ...
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# ---------------------------
# ...
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# ---------------------------

# %%
press(20,80, True)
# Out:
# ...
#   0%|                                                              | 0/80 [00:00<?, ?it/s]
# ---------------------------
# ...
#   0%|                                                              | 0/80 [00:00<?, ?it/s]
# ---------------------------

# %%
press(4,100)
# Out:
# ...
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# ---------------------------
# ...
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# ---------------------------

# %%
press(6,200)
# Out:
# ...
#   0%|                                                             | 0/200 [00:00<?, ?it/s]
# ---------------------------
# ...
#   0%|                                                             | 0/200 [00:00<?, ?it/s]
# ---------------------------

# %%
press(12,300)
# Out:
# ...
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# ---------------------------
# ...
#   0%|                                                             | 0/300 [00:00<?, ?it/s]
# ---------------------------

# %%
press(20,600)
# Out:
# ...
#   0%|                                                             | 0/600 [00:00<?, ?it/s]
# ---------------------------
# ...
#   0%|                                                             | 0/600 [00:00<?, ?it/s]
# ---------------------------

# %%
press(22,600)
# Out:
# ...
#   0%|                                                             | 0/600 [00:00<?, ?it/s]
# ---------------------------
# ...
#   0%|                                                             | 0/600 [00:00<?, ?it/s]

# %%
press(28,1200)

# %%
tFe = 0;  e1 =float(calc_j_gs_energy) ;e2 = float(g_run_cc_energy.energy.mean.real) 
e3 = float(exact_gs_energy);plot(exact_gs_energy,files,"(a)","RBM",L,tFe,it, e1,e2,e3)
# Out:
# ---------------------------

# %%
L = 6; it = 100; tFe = 0; trained_params_list = []; parameters_list = [];iii = [] 
mens, exact_gs_energy = exac_calc_lanczos_ed(tFe,L, True)
calc_j_gs_energy,j_out = jastrow_calc(tFe,L,it,True)
g_run_cc_energy,r_out, paths = rbm_fe(tFe,L,it,True,1)
files = [] ; files.append(j_out);files.append(r_out);
plot(exact_gs_energy,files,"(a)","RBM",L,tFe,it, 
     float(calc_j_gs_energy), float(g_run_cc_energy.energy.mean.real), float(exact_gs_energy))

tFe = 1
mens, exact_gs_energy = exac_calc_lanczos_ed(tFe,L, True)
calc_j_gs_energy,j_out = jastrow_calc(tFe,L,it,True)
g_run_cc_energy,r_out, paths = rbm(tFe,L,it,True,1)
files = [] ; files.append(j_out);files.append(r_out);
plot(exact_gs_energy,files,"(b)","RBM",L,tFe,it,
    float(calc_j_gs_energy), float(g_run_cc_energy.energy.mean.real), float(exact_gs_energy))
# Out:
# ...
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# ---------------------------
# ...
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# ---------------------------
# (-11.21110255092798, -11.21110218148781, -11.211122129048032)

# %%
L = 10; it = 600; trained_params_list = []; parameters_list = [];iii = [] 
mens, exact_gs_energy = exac_calc_lanczos_ed(0,L, True)
calc_j_gs_energy,j_out = jastrow_calc(0,L,it,True)
g_run_cc_energy,r_out, paths = rbm_fe(0,L,it,True,4)
files = [] ; files.append(j_out);files.append(r_out);files
plot(exact_gs_energy,files)
(float(exact_gs_energy),float(calc_j_gs_energy), float(g_run_cc_energy.energy.mean.real))
# Out:
# ...
#   0%|                                                             | 0/600 [00:00<?, ?it/s]
# (-10.000000000000028, -10.0, -10.0)

# %%
L = 10; it = 600; trained_params_list = []; parameters_list = [];iii = [] 
mens, exact_gs_energy = exac_calc_lanczos_ed(1,L, True)
calc_j_gs_energy,j_out = jastrow_calc(1,L,it,True)
g_run_cc_energy,r_out, paths = rbm(1,L,it,True,4)
# Out:
# ...
#   0%|                                                             | 0/600 [00:00<?, ?it/s]
# (-18.061785417968146, -18.04934246438006, -18.05989207710792)

# %%
L = 8; it = 100; trained_params_list = []; parameters_list = [];iii = [] 
mens, exact_gs_energy = exac_calc_lanczos_ed(1,L, True)
calc_j_gs_energy,j_out = jastrow_calc(1,L,it,True)
g_run_cc_energy,r_out, paths = rbm(1,L,it,True,3)
files = [] ; files.append(j_out);files.append(r_out);files
plot(exact_gs_energy,files)
(float(exact_gs_energy),float(calc_j_gs_energy), float(g_run_cc_energy.energy.mean.real))
# Out:
# ...
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# (-14.60437363574871, -14.601976941867797, -14.602673291036671)

# %%
L = 8; it = 400; trained_params_list = []; parameters_list = [];iii = [] 
mens, exact_gs_energy = exac_calc_lanczos_ed(1,L, True)
calc_j_gs_energy,j_out = jastrow_calc(1,L,it,True)
g_run_cc_energy,r_out, paths = rbm_fe(1,L,it,True,3)
files = [] ; files.append(j_out);files.append(r_out);files
plot(exact_gs_energy,files)
(float(exact_gs_energy),float(calc_j_gs_energy), float(g_run_cc_energy.energy.mean.real))
# Out:
# ...
#   0%|                                                             | 0/400 [00:00<?, ?it/s]
# (-14.604373635748706, -14.598694496823475, -14.547565639899648)

# %%
L = 20; it = 600; trained_params_list = []; parameters_list = [];iii = [] 
mens, exact_gs_energy = exac_calc_lanczos_ed(0,L, True)
calc_j_gs_energy,j_out = jastrow_calc(0,L,it,True)
g_run_cc_energy,r_out, paths = rbm_fe(0,L,it,True,3)
files = [] ; files.append(j_out);files.append(r_out);files
plot(exact_gs_energy,files)
(float(exact_gs_energy),float(calc_j_gs_energy), float(g_run_cc_energy.energy.mean.real))
# Out:
# ...
#   0%|                                                             | 0/600 [00:00<?, ?it/s]
# (-19.99999999999998, -20.00013657506115, -20.0)

# %%
L = 20; it = 1200; trained_params_list = []; parameters_list = [];iii = [] 
mens, exact_gs_energy = exac_calc_lanczos_ed(1,L, True)
calc_j_gs_energy,j_out = jastrow_calc(1,L,it,True)
g_run_cc_energy,r_out, paths = rbm(1,L,it,True,3)
files = [] ; files.append(j_out);files.append(r_out);files
plot(exact_gs_energy,files)
(float(exact_gs_energy),float(calc_j_gs_energy), float(g_run_cc_energy.energy.mean.real))
# Out:
# ...
#   0%|                                                            | 0/1200 [00:00<?, ?it/s]
# (-35.6175461195058, -35.561070243923034, -35.61831005987719)
