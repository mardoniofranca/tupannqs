# %%
# %run 0_config.ipynb

# %%
L = 12; it=200; tFe = 0; trained_params_list = []; parameters_list = [];iii = []; 
e_path1,mens,exact_gs_energy = exac_calc_lanczos_ed(tFe,L, True)
calc_j_gs_energy,j_out1 = jastrow_calc(tFe,L,it,True)
g_run_cc_energy,r_out1, paths1 = srbm(tFe,L,it,True,1)
# Out:
#   0%|                                                             | 0/200 [00:00<?, ?it/s]
# 1
#   0%|                                                             | 0/200 [00:00<?, ?it/s]

# %%
L = 12; it=200; tFe = 1; trained_params_list = []; parameters_list = [];iii = []; 
e_path2,mens,exact_gs_energy = exac_calc_lanczos_ed(tFe,L, True)
calc_j_gs_energy,j_out2 = jastrow_calc(tFe,L,it,True)
g_run_cc_energy,r_out2,paths2 = srbm(tFe,L,it,True,1)
# Out:
#   0%|                                                             | 0/200 [00:00<?, ?it/s]
#   0%|                                                             | 0/200 [00:00<?, ?it/s]

# %%
plot(e_path1, e_path2, j_out1, r_out1, j_out2, r_out2)

# %%
plotdx(paths1, 0, -1)
# Out:
# ['dataf/srbm_12_0_200_bias_real.csv', 'dataf/srbm_12_0_200_bias_img.csv', 'dataf/srbm_12_0_200_kernel_real.csv', 'dataf/srbm_12_0_200_kernel_img.csv']
# dataf/srbm_12_0_200_kernel_real.csv
# Métricas Estatísticas:
# ----------------------
# Média da diferença: 0.07
# Desvio padrão da diferença: 0.52
# Tamanho do efeito (Cohen's d): 0.14
# Magnitude da diferença (norma L2): 6.25

# %%
plotdx(paths2, 0, -1)
# Out:
# ['dataf/srbm_12_1_200_bias_real.csv', 'dataf/srbm_12_1_200_bias_img.csv', 'dataf/srbm_12_1_200_kernel_real.csv', 'dataf/srbm_12_1_200_kernel_img.csv']
# dataf/srbm_12_1_200_kernel_real.csv
# Métricas Estatísticas:
# ----------------------
# Média da diferença: 0.00
# Desvio padrão da diferença: 0.45
# Tamanho do efeito (Cohen's d): 0.00
# Magnitude da diferença (norma L2): 1.51

# %%
plotdx(paths, 0, -1)
# Out:
# ['dataf/srbm_22_0_200_bias_real.csv', 'dataf/srbm_22_0_200_bias_img.csv', 'dataf/srbm_22_0_200_kernel_real.csv', 'dataf/srbm_22_0_200_kernel_img.csv']
# dataf/srbm_22_0_200_kernel_real.csv
# Métricas Estatísticas:
# ----------------------
# Média da diferença: 0.24
# Desvio padrão da diferença: 2.22
# Tamanho do efeito (Cohen's d): 0.11
# Magnitude da diferença (norma L2): 14.66

# %%
plotdp(paths1, 0,-1)
# Out:
# Figure saved to dist_w/s4.png

# %%
plotdp(paths2, 0,-1)
# Out:
# Figure saved to dist_w/s4.png
