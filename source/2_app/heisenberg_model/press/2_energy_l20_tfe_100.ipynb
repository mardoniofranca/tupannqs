# %%
# %run 0_config.ipynb

# %%
L = 22; it=200; tFe = 0; trained_params_list = []; parameters_list = [];iii = [];

# %%
mens, exact_gs_energy = exac_calc_lanczos_ed(tFe,L, True)
calc_j_gs_energy,j_out = jastrow_calc(tFe,L,it,True)

# %%
g_run_cc_energy,r_out, paths = srbm(tFe,L,it,True,0.5)
# Out:
# 0.5
#   0%|                                                             | 0/200 [00:00<?, ?it/s]

# %%
paths
# Out:
# ['dataf/srbm_22_0_200_bias_real.csv',
#  'dataf/srbm_22_0_200_bias_img.csv',
#  'dataf/srbm_22_0_200_kernel_real.csv',
#  'dataf/srbm_22_0_200_kernel_img.csv']

# %%
paths[2]
# Out:
# 'dataf/srbm_22_0_200_kernel_real.csv'

# %%
df = pd.read_csv(paths[2])

# %%
df.shape
# Out:
# (200, 243)

# %%
plot()

# %%
plotdx(paths, 0, -1)
# Out:
# ['dataf/srbm_22_0_200_bias_real.csv', 'dataf/srbm_22_0_200_bias_img.csv', 'dataf/srbm_22_0_200_kernel_real.csv', 'dataf/srbm_22_0_200_kernel_img.csv']
# dataf/srbm_22_0_200_kernel_real.csv
# Métricas Estatísticas:
# ----------------------
# Média da diferença: 0.05
# Desvio padrão da diferença: 0.58
# Tamanho do efeito (Cohen's d): 0.08
# Magnitude da diferença (norma L2): 9.11

# %%
plotdx(paths, 0, -1)
# Out:
# ['dataf/srbm_22_0_200_bias_real.csv', 'dataf/srbm_22_0_200_bias_img.csv', 'dataf/srbm_22_0_200_kernel_real.csv', 'dataf/srbm_22_0_200_kernel_img.csv']
# dataf/srbm_22_0_200_kernel_real.csv
# Métricas Estatísticas:
# ----------------------
# Média da diferença: 0.24
# Desvio padrão da diferença: 2.22
# Tamanho do efeito (Cohen's d): 0.11
# Magnitude da diferença (norma L2): 14.66

# %%
plotdp(paths, 0,-1)
# Out:
# Figure saved to dist_w/s4.png

# %%
plotdp(paths, 0,-1)
# Out:
# Figure saved to dist_w/s4.png

# %%
plotdp(paths, 0,-1)
# Out:
# Figure saved to dist_w/s4.png

# %%
g_run_cc_energy,r_out, paths = srbm(tFe,L,it,True,2)
# Out:
# 2
#   0%|                                                             | 0/200 [00:00<?, ?it/s]

# %%
plotdp(paths, 0,-1)
# Out:
# Figure saved to dist_w/s4.png
