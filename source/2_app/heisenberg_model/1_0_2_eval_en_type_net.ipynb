# %%
# %run 0_config.ipynb

# %% [markdown]
# energy_text = (
#     "Métodos Variacionais\n"
#     f"{'Energia (Jastrow)':<20}: {e1:.4f}\n"
#     f"{'Energia (SRBM)'   :<20}: {e2:.4f}\n"
#     f"{'Energia (FFNN)'   :<20}: {e3:.4f}\n"
#     f"{'Energia (M-FFNN)' :<20}: {e4:.4f}\n"
#     "\nReferência\n"
#     f"{'Energia (Exata)'  :<20}: {e5:.4f}"
# )

# %%
L = 12; it=80; tFe = 1; trained_params_list = []; parameters_list = [];iii = []; x_axis = False
mens, exact_gs_energy = exac_calc_lanczos_ed(tFe,L, True)
calc_j_gs_energy,j_out = jastrow_calc(tFe,L,it,True)
g_run_cc_energy,r_out, paths = rbm(tFe,L,it,True,1)
files = [] ; files.append(j_out);files.append(r_out);

plot(exact_gs_energy,files,"(b)","RBM",L,tFe,it, 
     float(calc_j_gs_energy), float(g_run_cc_energy.energy.mean.real), float(exact_gs_energy),x_axis, False,0 )
# Out:
# ...
#   0%|                                                              | 0/80 [00:00<?, ?it/s]
# ---------------------------

# %%
L = 12; it=80; tFe = 0; trained_params_list = []; parameters_list = [];iii = []; x_axis = False
mens, exact_gs_energy = exac_calc_lanczos_ed(tFe,L, True)
calc_j_gs_energy,j_out = jastrow_calc(tFe,L,it,True)
g_run_cc_energy,r_out, paths = rbm_fe(tFe,L,it,True,1)
files = [] ; files.append(j_out);files.append(r_out);
# Out:
# ...
#   0%|                                                              | 0/80 [00:00<?, ?it/s]

# %%
plot(exact_gs_energy,files,"(a)","RBM",L,tFe,it, 
     float(calc_j_gs_energy), float(g_run_cc_energy.energy.mean.real), float(exact_gs_energy),x_axis, True,0 )
# Out:
# [11.939290121039944, 2.8576309001875813, -8.001313867683606, -11.35254902207985, -11.927434199674702, -11.978618921609332, -11.991761806388515, -11.945163855036622]
# 8
# hiiiiiiiiiiiii
# RBM
# ---------------------------

# %%
L = 20; it=80; tFe = 0; trained_params_list = []; parameters_list = [];iii = []; x_axis = False
mens, exact_gs_energy = exac_calc_lanczos_ed(tFe,L, True)
calc_j_gs_energy,j_out = jastrow_calc(tFe,L,it,True)
g_run_cc_energy,r_out, paths = rbm_fe(tFe,L,it,True,1)
files = [] ; files.append(j_out);files.append(r_out);
# Out:
# ...
#   0%|                                                              | 0/80 [00:00<?, ?it/s]

# %%
plot(exact_gs_energy,files,"(c)","RBM",L,tFe,it, 
     float(calc_j_gs_energy), float(g_run_cc_energy.energy.mean.real), float(exact_gs_energy),True, True,0 )
# Out:
# ---------------------------

# %%
L = 20; it=80; tFe = 1; trained_params_list = []; parameters_list = [];iii = []; x_axis = False
mens, exact_gs_energy = exac_calc_lanczos_ed(tFe,L, True)
calc_j_gs_energy,j_out = jastrow_calc(tFe,L,it,True)
g_run_cc_energy,r_out, paths = rbm(tFe,L,it,True,1)
files = [] ; files.append(j_out);files.append(r_out);
# Out:
# ...
#   0%|                                                              | 0/80 [00:00<?, ?it/s]

# %%
plot(exact_gs_energy,files,"(d)","RBM",L,tFe,it, 
     float(calc_j_gs_energy), float(g_run_cc_energy.energy.mean.real), float(exact_gs_energy),True, False,0 )
# Out:
# ---------------------------

# %%
L = 22; it=100; tFe = 1; trained_params_list = []; parameters_list = [];iii = []; x_axis = False
mens, exact_gs_energy = exac_calc_lanczos_ed(tFe,L, True)
calc_j_gs_energy,j_out = jastrow_calc(tFe,L,it,True)
g_run_cc_energy,r_out, paths = rbm(tFe,L,it,True,1)
files = [] ; files.append(j_out);files.append(r_out);

plot(exact_gs_energy,files,"(a)","RBM",L,tFe,it, 
     float(calc_j_gs_energy), float(g_run_cc_energy.energy.mean.real), float(exact_gs_energy),x_axis, True,0 )

g_run_cc_energy,r_out, paths = srbm(tFe,L,it,True,1)
files = [] ; files.append(j_out);files.append(r_out);
plot(exact_gs_energy,files,"(b)","SRBM",L,tFe,it, 
     float(calc_j_gs_energy), float(g_run_cc_energy.energy.mean.real), float(exact_gs_energy),x_axis, True,1 )

g_run_cc_energy,r_out, paths = ffnn(tFe,L,it,True,1)
files = [] ; files.append(j_out);files.append(r_out);
plot(exact_gs_energy,files,"(C)","FFNN",L,tFe,it, 
     float(calc_j_gs_energy), float(g_run_cc_energy.energy.mean.real), float(exact_gs_energy),x_axis, 
     True,2 )

g_run_cc_energy,r_out, paths = ffnn2(tFe,L,it,True,1)
files = [] ; files.append(j_out);files.append(r_out);
plot(exact_gs_energy,files,"(d)","FFNN2",L,tFe,it, 
     float(calc_j_gs_energy), float(g_run_cc_energy.energy.mean.real), float(exact_gs_energy),x_axis, 
     True,2 )
# Out:
# ...
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# ---------------------------
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# ---------------------------
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# ---------------------------
#   0%|                                                             | 0/100 [00:00<?, ?it/s]
# ---------------------------

# %%
L = 22; it=100; tFe = 1; trained_params_list = []; parameters_list = [];iii = []; x_axis = False
mens, exact_gs_energy = exac_calc_lanczos_ed(tFe,L, True)
calc_j_gs_energy,j_out = jastrow_calc(tFe,L,it,True)
g_run_cc_energy,r_out, paths = rbm(tFe,L,it,True,1)
files = [] ; files.append(j_out);files.append(r_out);
plot(exact_gs_energy,files,"(a)","RBM",L,tFe,it, 
     float(calc_j_gs_energy), float(g_run_cc_energy.energy.mean.real), float(exact_gs_energy),x_axis, True,0 )
# Out:
# ...
#   0%|                                                              | 0/50 [00:00<?, ?it/s]
# ---------------------------

# %%
L = 14; it=50; tFe = 1; trained_params_list = []; parameters_list = [];iii = []; x_axis = False
mens, exact_gs_energy = exac_calc_lanczos_ed(tFe,L, True)
calc_j_gs_energy,j_out = jastrow_calc(tFe,L,it,True)
g_run_cc_energy,r_out, paths = srbm(tFe,L,it,True,1)
files = [] ; files.append(j_out);files.append(r_out);

plot(exact_gs_energy,files,"(b)","SRBM",L,tFe,it, 
     float(calc_j_gs_energy), float(g_run_cc_energy.energy.mean.real), float(exact_gs_energy),x_axis, True,1 )
# Out:
# ---------------------------

# %%
L = 20; it=50; tFe = 1; trained_params_list = []; parameters_list = [];iii = []; x_axis = False
mens, exact_gs_energy = exac_calc_lanczos_ed(tFe,L, True)
calc_j_gs_energy,j_out = jastrow_calc(tFe,L,it,True)
g_run_cc_energy,r_out, paths = ffnn(tFe,L,it,True,1)
files = [] ; files.append(j_out);files.append(r_out);
plot(exact_gs_energy,files,"(c)","FFNN",L,tFe,it, 
     float(calc_j_gs_energy), float(g_run_cc_energy.energy.mean.real), float(exact_gs_energy),x_axis, 
     True,2 )
# Out:
# ...
#   0%|                                                              | 0/50 [00:00<?, ?it/s]
# ---------------------------

# %%
# %run 0_config.ipynb

# %%
tFe
# Out:
# 0

# %%
plot(exact_gs_energy,files,"(c)","RBM",L,tFe,it, 
     float(calc_j_gs_energy), float(g_run_cc_energy.energy.mean.real), float(exact_gs_energy),x_axis, 
     True,0)
# Out:
# ---------------------------

# %%
# %run 0_config.ipynb

# %%
L = 20; it=80; tFe = 0; trained_params_list = []; parameters_list = [];iii = []; x_axis = True
mens, exact_gs_energy = exac_calc_lanczos_ed(tFe,L, True)
calc_j_gs_energy,j_out = jastrow_calc(tFe,L,it,True)
g_run_cc_energy,r_out, paths = rbm(tFe,L,it,True,1)
files = [] ; files.append(j_out);files.append(r_out);
plot(exact_gs_energy,files,"(c)","RBM",L,tFe,it, 
     float(calc_j_gs_energy), float(g_run_cc_energy.energy.mean.real), float(exact_gs_energy),x_axis, 
     True,0)
# Out:
# ...
#   0%|                                                              | 0/80 [00:00<?, ?it/s]
# ---------------------------

# %%
L = 20; it=80; tFe = 1; trained_params_list = []; parameters_list = [];iii = []; x_axis = True
mens, exact_gs_energy = exac_calc_lanczos_ed(tFe,L, True)
calc_j_gs_energy,j_out = jastrow_calc(tFe,L,it,True)
g_run_cc_energy,r_out, paths = rbm(tFe,L,it,True,1)
files = [] ; files.append(j_out);files.append(r_out);
plot(exact_gs_energy,files,"(d)","RBM",L,tFe,it, 
     float(calc_j_gs_energy), float(g_run_cc_energy.energy.mean.real), float(exact_gs_energy),x_axis, 
     False,0)
# Out:
# ...
#   0%|                                                              | 0/80 [00:00<?, ?it/s]
# ---------------------------

# %%
r_out
# Out:
# 'out/params/ffnn_20_1_50'
